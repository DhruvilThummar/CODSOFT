# %% [markdown]
# # Movie Genre Classification
#
# Create a machine learning model that can predict the genre of a movie based on its plot summary or other textual information.
#
# ## Objective
# Predict the correct genre category using Natural Language Processing (NLP) techniques (TF-IDF) combined with classification algorithms like Naive Bayes, Logistic Regression, and Support Vector Machines. We compare performance across models and evaluate them on an independent test dataset.

# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import nltk
from nltk.corpus import stopwords
import time
from tqdm import tqdm

# Set seaborn plotting style
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ### Libraries and Configuration
# We have imported:
# - `pandas` and `numpy` for data manipulation.
# - `matplotlib.pyplot` and `seaborn` for creating data visualizations.
# - `scikit-learn` libraries for text feature extraction (`TfidfVectorizer`), cross-validation split (`train_test_split`), classification algorithms (`MultinomialNB`, `LogisticRegression`, `LinearSVC`), and metric generation.
# - `nltk` for downloading English stopwords.
# - `tqdm` for tracking application progress.

# %%
# Paths to the downloaded text datasets
dataset_dir = "Genre_Classification_Dataset"
train_path = os.path.join(dataset_dir, "train_data.txt")
test_sol_path = os.path.join(dataset_dir, "test_data_solution.txt")

# Load datasets
train_df = pd.read_csv(
    train_path,
    sep=' ::: ',
    engine='python',
    names=['id', 'title', 'genre', 'description'],
    header=None
)
test_df = pd.read_csv(
    test_sol_path,
    sep=' ::: ',
    engine='python',
    names=['id', 'title', 'genre', 'description'],
    header=None
)

print(f"Train dataset shape: {train_df.shape}")
print(f"Test dataset shape: {test_df.shape}")
train_df.head()
# Out:
# Train dataset shape: (2110, 4)
# Test dataset shape: (3670, 4)
#    id                             title     genre  \
# 0   1      Oscar et la dame rose (2009)     drama
# 1   2                      Cupid (1997)  thriller
# 2   3  Young, Wild and Wonderful (1980)     adult
# 3   4             The Secret Sin (1915)     drama
# 4   5            The Unrecovered (2007)     drama
#
#                                          description
# 0  Listening in to a conversation between his doc...
# 1  A brother and sister with a past incestuous re...
# 2  As the bus empties the students for their fiel...
# 3  To help their unemployed father make ends meet...
# 4  The film's title refers not only to the un-rec...
